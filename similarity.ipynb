# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import pickle

# %%
actors = pd.read_csv('archive//actors.csv')
actors
# Out:
#               id               name                 role
# 0        1000001      Margot Robbie               Barbie
# 1        1000001       Ryan Gosling                  Ken
# 2        1000001    America Ferrera               Gloria
# 3        1000001  Ariana Greenblatt                Sasha
# 4        1000001           Issa Rae               Barbie
# ...          ...                ...                  ...
# 5798445  1941596            Marc Ma            Ba Cai/巴莱
# 5798446  1941596                线雨轩              Tata/塔塔
# 5798447  1941596       Jiang Yixuan  Zuo Yila（Zoila）/佐伊拉
# 5798448  1941597     Hiroshi Mikami                  NaN
# 5798449  1941597      Keiko Oginome                  NaN
#
# [5798450 rows x 3 columns]

# %%
actors = actors.groupby('id')['name'].agg(
    lambda x: '|'.join(
        set(', '.join(x.dropna().astype(str)).split(', '))
    )
).reset_index()
actors.rename(columns={'name': 'actors'}, inplace=True)
actors
# Out:
#              id                                             actors
# 0       1000001  Alex Sturman|Sia Dauda|George Basil|Cristian L...
# 1       1000002  Jung Ji-so|Jeong Ik-han|Kim Geon|Jeon Eun-mi|S...
# 2       1000003  Anthony Molinari|Daniel Scheinert|Tallie Medel...
# 3       1000004  Christie Cronenweth|Robby Robinson|Bennie Moor...
# 4       1000005  Morgan Larson|Emma Stone|Brandon O'Neal|Tommy ...
# ...         ...                                                ...
# 634297  1941559                                                 黑灯
# 634298  1941563  Pan Binlong|黄子弘凡|Li Jian|Zhang Youhao|Lan Xiya...
# 634299  1941589                                                王军锋
# 634300  1941596  线雨轩|Marc Ma|Sandrine Pinna|Jiang Yixuan|Ethan ...
# 634301  1941597                       Keiko Oginome|Hiroshi Mikami
#
# [634302 rows x 2 columns]

# %%
countries = pd.read_csv('archive//countries.csv')
countries
# Out:
#              id      country
# 0       1000001           UK
# 1       1000001          USA
# 2       1000002  South Korea
# 3       1000003          USA
# 4       1000004      Germany
# ...         ...          ...
# 693471  1941593        China
# 693472  1941594          USA
# 693473  1941595          USA
# 693474  1941596        China
# 693475  1941597        Japan
#
# [693476 rows x 2 columns]

# %%
countries = countries.groupby('id')['country'].agg(
    lambda x: '|'.join(
        set(', '.join(x.dropna().astype(str)).split(', '))
    )
).reset_index()
countries.rename(columns={'country': 'countries'}, inplace=True)
countries
# Out:
#              id      countries
# 0       1000001         UK|USA
# 1       1000002    South Korea
# 2       1000003            USA
# 3       1000004    Germany|USA
# 4       1000005  Hong Kong|USA
# ...         ...            ...
# 617187  1941593          China
# 617188  1941594            USA
# 617189  1941595            USA
# 617190  1941596          China
# 617191  1941597          Japan
#
# [617192 rows x 2 columns]

# %%
crew = pd.read_csv('archive//crew.csv')
crew
# Out:
#               id            role                  name
# 0        1000001        Director          Greta Gerwig
# 1        1000001        Producer          Tom Ackerley
# 2        1000001        Producer         Margot Robbie
# 3        1000001        Producer        Robbie Brenner
# 4        1000001        Producer          David Heyman
# ...          ...             ...                   ...
# 4720178  1941596         Casting                   线雨轩
# 4720179  1941596          Editor  Eric Kwong Chi-Leung
# 4720180  1941596  Cinematography             Kenny Tse
# 4720181  1941596        Composer                   胡小欧
# 4720182  1941596  Costume design           Kenneth Yee
#
# [4720183 rows x 3 columns]

# %%
crew = (
    crew.groupby(['id', 'role'])['name']
    .agg(lambda x: '|'.join(x.dropna().astype(str)))
    .unstack()
    .reset_index()
)
crew
# Out:
# role         id         Additional directing Additional photography  \
# 0       1000001  George Cottle|John Sorapure          John Sorapure
# 1       1000002                Lee Jung-hoon               Lee Hyun
# 2       1000003                          NaN         Kanamé Onoyama
# 3       1000004                          NaN            Steve Wolfe
# 4       1000005                          NaN                    NaN
# ...         ...                          ...                    ...
# 807057  1941552                          NaN                    NaN
# 807058  1941560                          NaN                    NaN
# 807059  1941563                          NaN                    NaN
# 807060  1941589                          NaN                    NaN
# 807061  1941596                          NaN                    NaN
#
# role                                        Art direction  \
# 0       David Doran|Jordana Finkel|Clara Gomez del Mor...
# 1                                                Mo So-ra
# 2                                           Amelia Brooke
# 3         Chris Gorak|Seth Reed|Josue Clotaire Fleurimond
# 4                            Austin Gorg|Steven Light-Orr
# ...                                                   ...
# 807057                                                NaN
# 807058                                                NaN
# 807059                                                NaN
# 807060                                                NaN
# 807061                                                NaN
#
# role                                   Assistant director  \
# 0       David Keadell|Danni Lizaitis|Josh Robertson|Ma...
# 1                            Kim Seong-sik|Yoon Young-woo
# 2                                 Rod Smith|John Nasraway
# 3                               Bob Wagner|Mike Topoozian
# 4                                   Paula Case|Peter Kohn
# ...                                                   ...
# 807057                                                NaN
# 807058                                                NaN
# 807059                                                NaN
# 807060                                                NaN
# 807061                                                NaN
#
# role                                      Camera operator  \
# 0                                 Chris Bain|Simon Finney
# 1                                         Yang Hyeon-seok
# 2       Aaron M. Smith|Alex Kornreich|Mario Contini|Ar...
# 3                           Conrad W. Hall|Chris Haarhoff
# 4                             Ari Robbins|Davon Slininger
# ...                                                   ...
# 807057                                                NaN
# 807058                                                NaN
# 807059                                                NaN
# 807060                                                NaN
# 807061                                                NaN
#
# role                                              Casting    Choreography  \
# 0       Lucy Bevan|Allison Jones|Olivia Grant|Emily Bu...  Jennifer White
# 1                                                     NaN             NaN
# 2                       Sarah Halley Finn|Djinous Rowling             NaN
# 3                            Laray Mayfield|Karen Meisels             NaN
# 4                              Deborah Aquila|Tricia Wood     Mandy Moore
# ...                                                   ...             ...
# 807057                                                NaN             NaN
# 807058                                                NaN             NaN
# 807059                                                NaN             NaN
# 807060                                                NaN             NaN
# 807061                                                线雨轩             NaN
#
# role     Cinematography Co-director  ... Production design  \
# 0        Rodrigo Prieto         NaN  ...   Sarah Greenwood
# 1        Hong Kyung-pyo         NaN  ...        Lee Ha-jun
# 2         Larkin Seiple         NaN  ...   Jason Kisvarday
# 3       Jeff Cronenweth         NaN  ...     Alex McDowell
# 4        Linus Sandgren         NaN  ...       David Wasco
# ...                 ...         ...  ...               ...
# 807057              NaN         NaN  ...               NaN
# 807058              NaN         NaN  ...               NaN
# 807059              NaN         NaN  ...               NaN
# 807060              NaN         NaN  ...               NaN
# 807061        Kenny Tse         NaN  ...               NaN
#
# role                                       Set decoration  \
# 0       Katie Spencer|Ashley Swanson|Trixie Gardner|An...
# 1                  Cho Won-woo|Noh Seung-goog|Song Suk-ki
# 2       Kelsi Ephraim|Lia Burton|Hunter Gorton|Sierra ...
# 3       Jay Hart|Luis G. Hoyos|Hugo Santiago|Peter J. ...
# 4       Sandy Reynolds-Wasco|Jennie Harris|Daniel Brad...
# ...                                                   ...
# 807057                                                NaN
# 807058                                                NaN
# 807059                                                NaN
# 807060                                                NaN
# 807061                                                NaN
#
# role                                                Songs  \
# 0       Dua Lipa|Charli XCX|Billie Eilish|Finneas O'Co...
# 1                  Choi Woo-shik|Park Hyo-shin|Lee Ji-hye
# 2                                      Mitski|David Byrne
# 3                                                     NaN
# 4       Benj Pasek|Justin Paul|Justin Hurwitz|Damien C...
# ...                                                   ...
# 807057                                                NaN
# 807058                                                NaN
# 807059                                                NaN
# 807060                                                NaN
# 807061                                                NaN
#
# role                                                Sound  \
# 0       Robert Sharman|Chelsea Body|Dan Kenyon|Ai-Ling...
# 1       Choi Tae-young|Eun Hee-soo|Shin i Na|Kim Byung...
# 2       Jason Charbonneau|Ian Chase|Alexandra Fehrman|...
# 3       Ren Klyce|Richard Hymns|Steve Boeddeker|Jeff W...
# 4       Kevin Becker|James Ashwill|Blake Collins|John ...
# ...                                                   ...
# 807057                                                NaN
# 807058                                                NaN
# 807059                                                NaN
# 807060                                                NaN
# 807061                                                NaN
#
# role                                      Special effects         Story  \
# 0       Lucy Thompson|Alex Robinson|Peter Treece|Sam P...           NaN
# 1                                                     NaN  Bong Joon-ho
# 2                      Charlie Bruchez|Jonathan Kombrinck           NaN
# 3                               Cliff Wenger|Wayne Burnes           NaN
# 4                                             Jeremy Hays           NaN
# ...                                                   ...           ...
# 807057                                                NaN           NaN
# 807058                                                NaN           NaN
# 807059                                                NaN           NaN
# 807060                                                NaN           NaN
# 807061                                                NaN           NaN
#
# role                                               Stunts   Title design  \
# 0       Ingrid Kleinig|Roy Taylor|Donny Bailey|Hannah ...            NaN
# 1       Yoo Sang-seob|Oh Se-yeong|Yoo Mi-jin|Kwon Ji-h...            NaN
# 2       Narayana Cabral|Elisabeth P. Carpenter|Timothy...            NaN
# 3       Michael Runyard|Jeff Imada|Richard Cetrone|Dav...            NaN
# 4       Nicolas Bosc|Brandon Cornell|Olivia Courtney|D...  Michael Riley
# ...                                                   ...            ...
# 807057                                                NaN            NaN
# 807058                                                NaN            NaN
# 807059                                                NaN            NaN
# 807060                                                NaN            NaN
# 807061                                                NaN            NaN
#
# role                                       Visual effects  \
# 0       Nick Irving Allen|François Dumoulin|Erin Hewit...
# 1       Hong Jeong-ho|Chan-jin Chris Kim|Jang Mi-jin|K...
# 2       Evan Halleck|Zak Stoltz|Jeff Desom|Ethan Feldb...
# 3       Carlos Saldanha|Joshua I. Kolden|Andrea D'Amic...
# 4                   Chris LeDoux|Tim LeDoux|Jason Sanford
# ...                                                   ...
# 807057                                                NaN
# 807058                                                NaN
# 807059                                                NaN
# 807060                                                NaN
# 807061                                                NaN
#
# role                                   Writer
# 0                  Noah Baumbach|Greta Gerwig
# 1       Kim Dae-hwan|Bong Joon-ho|Han Jin-won
# 2                Daniel Kwan|Daniel Scheinert
# 3                Jim Uhls|Andrew Kevin Walker
# 4                             Damien Chazelle
# ...                                       ...
# 807057                                    NaN
# 807058                                    NaN
# 807059                                    NaN
# 807060                                    NaN
# 807061          Marc Ma|Haoran Gu|Zhao Haozhe
#
# [807062 rows x 30 columns]

# %%
genres = pd.read_csv('archive//genres.csv')
genres
# Out:
#               id      genre
# 0        1000001     Comedy
# 1        1000001  Adventure
# 2        1000002     Comedy
# 3        1000002   Thriller
# 4        1000002      Drama
# ...          ...        ...
# 1046844  1941563      Drama
# 1046845  1941566      Crime
# 1046846  1941569      Crime
# 1046847  1941596     Action
# 1046848  1941596      Crime
#
# [1046849 rows x 2 columns]

# %%
genres = genres.groupby('id')['genre'].agg(
    lambda x: '|'.join(
        set(', '.join(x.dropna().astype(str)).split(', '))
    )
).reset_index()
genres.rename(columns={'genre': 'genres'}, inplace=True)
genres
# Out:
#              id                                   genres
# 0       1000001                         Comedy|Adventure
# 1       1000002                    Comedy|Drama|Thriller
# 2       1000003  Comedy|Action|Science Fiction|Adventure
# 3       1000004                                    Drama
# 4       1000005               Comedy|Drama|Romance|Music
# ...         ...                                      ...
# 676486  1941559                                   Comedy
# 676487  1941563                                    Drama
# 676488  1941566                                    Crime
# 676489  1941569                                    Crime
# 676490  1941596                             Action|Crime
#
# [676491 rows x 2 columns]

# %%
languages = pd.read_csv('archive//languages.csv')
languages
# Out:
#               id              type  language
# 0        1000001          Language   English
# 1        1000002  Primary language    Korean
# 2        1000002   Spoken language   English
# 3        1000002   Spoken language    German
# 4        1000002   Spoken language    Korean
# ...          ...               ...       ...
# 1038757  1941593          Language   Chinese
# 1038758  1941594          Language   English
# 1038759  1941595          Language   English
# 1038760  1941596          Language   Chinese
# 1038761  1941597          Language  Japanese
#
# [1038762 rows x 3 columns]

# %%
languages = (
    languages.groupby(['id', 'type'])['language']
    .agg(lambda x: '|'.join(x.dropna().astype(str)))
    .unstack()
    .reset_index()
)
languages
# Out:
# type         id  Language Primary language            Spoken language
# 0       1000001   English              NaN                        NaN
# 1       1000002       NaN           Korean      English|German|Korean
# 2       1000003       NaN          English  Cantonese|Chinese|English
# 3       1000004   English              NaN                        NaN
# 4       1000005   English              NaN                        NaN
# ...         ...       ...              ...                        ...
# 905573  1941593   Chinese              NaN                        NaN
# 905574  1941594   English              NaN                        NaN
# 905575  1941595   English              NaN                        NaN
# 905576  1941596   Chinese              NaN                        NaN
# 905577  1941597  Japanese              NaN                        NaN
#
# [905578 rows x 4 columns]

# %%
movies = pd.read_csv('archive//movies.csv')
movies
# Out:
#              id                               name    date  \
# 0       1000001                             Barbie  2023.0
# 1       1000002                           Parasite  2019.0
# 2       1000003  Everything Everywhere All at Once  2022.0
# 3       1000004                         Fight Club  1999.0
# 4       1000005                         La La Land  2016.0
# ...         ...                                ...     ...
# 941592  1941593                                 神笛     NaN
# 941593  1941594                      蟲極道蜜団子抗争編 壱ノ巻     NaN
# 941594  1941595                      蟲極道蜜団子抗争編 弐ノ巻     NaN
# 941595  1941596                                 重生     NaN
# 941596  1941597                             青ひげ公の城     NaN
#
#                                                  tagline  \
# 0                       She's everything. He's just Ken.
# 1                            Act like you own the place.
# 2       The universe is so much bigger than you realize.
# 3                                Mischief. Mayhem. Soap.
# 4                         Here's to the fools who dream.
# ...                                                  ...
# 941592                                               NaN
# 941593                                               NaN
# 941594                                               NaN
# 941595                                               NaN
# 941596                                               NaN
#
#                                               description  minute  rating
# 0       Barbie and Ken are having the time of their li...   114.0    3.86
# 1       All unemployed, Ki-taek's family takes peculia...   133.0    4.56
# 2       An aging Chinese immigrant is swept up in an i...   140.0    4.30
# 3       A ticking-time-bomb insomniac and a slippery s...   139.0    4.27
# 4       Mia, an aspiring actress, serves lattes to mov...   129.0    4.09
# ...                                                   ...     ...     ...
# 941592                                                NaN     NaN     NaN
# 941593  Shinjuku forest at night. In the sap taverns o...    30.0     NaN
# 941594  The city that never sleeps, where insects gath...    30.0     NaN
# 941595  In a world where order has broken down, darkne...     NaN     NaN
# 941596                                                NaN   130.0     NaN
#
# [941597 rows x 7 columns]

# %%
posters = pd.read_csv('archive//posters.csv')
posters.rename(columns={'link': 'poster'}, inplace=True)
posters
# Out:
#              id                                             poster
# 0       1000001  https://a.ltrbxd.com/resized/film-poster/2/7/7...
# 1       1000002  https://a.ltrbxd.com/resized/film-poster/4/2/6...
# 2       1000003  https://a.ltrbxd.com/resized/film-poster/4/7/4...
# 3       1000004  https://a.ltrbxd.com/resized/film-poster/5/1/5...
# 4       1000005  https://a.ltrbxd.com/resized/film-poster/2/4/0...
# ...         ...                                                ...
# 941592  1941593                                                NaN
# 941593  1941594                                                NaN
# 941594  1941595  https://a.ltrbxd.com/resized/film-poster/1/1/8...
# 941595  1941596  https://a.ltrbxd.com/resized/film-poster/1/1/8...
# 941596  1941597                                                NaN
#
# [941597 rows x 2 columns]

# %%
releases = pd.read_csv('archive//releases.csv')
releases
# Out:
#               id    country        date        type rating
# 0        1000001    Andorra  2023-07-21  Theatrical    NaN
# 1        1000001  Argentina  2023-07-20  Theatrical    ATP
# 2        1000001  Australia  2023-07-19  Theatrical     PG
# 3        1000001  Australia  2023-10-01     Digital     PG
# 4        1000001    Austria  2023-07-20  Theatrical    NaN
# ...          ...        ...         ...         ...    ...
# 1332777  1940967        USA  1909-01-01  Theatrical    NaN
# 1332778  1940968     Sweden  1908-11-11  Theatrical    NaN
# 1332779  1940969     France  1902-01-01  Theatrical    NaN
# 1332780  1940970     France  1902-01-01  Theatrical    NaN
# 1332781  1940971     France  1902-01-01  Theatrical    NaN
#
# [1332782 rows x 5 columns]

# %%
studios = pd.read_csv('archive//studios.csv')
studios
# Out:
#              id                   studio
# 0       1000001  LuckyChap Entertainment
# 1       1000001             Heyday Films
# 2       1000001           NB/GG Pictures
# 3       1000001                   Mattel
# 4       1000001    Warner Bros. Pictures
# ...         ...                      ...
# 679278  1941596               上海猫眼影业有限公司
# 679279  1941596            坏小子（北京）传媒有限公司
# 679280  1941596         亚太国影（重庆）文化传媒有限公司
# 679281  1941596               凤凰传奇影业有限公司
# 679282  1941596             无双（深圳）影业有限公司
#
# [679283 rows x 2 columns]

# %%
studios = studios.groupby('id')['studio'].agg(
    lambda x: '|'.join(
        set(', '.join(x.dropna().astype(str)).split(', '))
    )
).reset_index()
studios.rename(columns={'studio': 'studios'}, inplace=True)
studios
# Out:
#              id                                            studios
# 0       1000001  NB/GG Pictures|Warner Bros. Pictures|Heyday Fi...
# 1       1000002                                       Barunson E&A
# 2       1000003  Year of the Rat|IAC Films|Ley Line Entertainme...
# 3       1000004  Regency Enterprises|20th Century Fox|Taurus Fi...
# 4       1000005  Summit Entertainment|Gilbert Films|Marc Platt ...
# ...         ...                                                ...
# 438192  1941538                                     Helsinki-filmi
# 438193  1941539                                 Onza Entertainment
# 438194  1941541                                      Enlight Media
# 438195  1941557                                                 滚石
# 438196  1941596  坏小子（北京）传媒有限公司|亚太国影（重庆）文化传媒有限公司|凤凰传奇影业有限公司|上海猫眼...
#
# [438197 rows x 2 columns]

# %%
themes = pd.read_csv('archive//themes.csv')
themes
# Out:
#              id                                              theme
# 0       1000001                   Humanity and the world around us
# 1       1000001                             Crude humor and satire
# 2       1000001                        Moving relationship stories
# 3       1000001     Emotional and captivating fantasy storytelling
# 4       1000001  Surreal and thought-provoking visions of life ...
# ...         ...                                                ...
# 125636  1835643                         Noir and dark crime dramas
# 125637  1835643        Intriguing and suspenseful murder mysteries
# 125638  1849827                                 Faith and religion
# 125639  1849827                       Faith and spiritual journeys
# 125640  1849827              Religious faith, sin, and forgiveness
#
# [125641 rows x 2 columns]

# %%
themes = themes.groupby('id')['theme'].agg(
    lambda x: '|'.join(
        set(', '.join(x.dropna().astype(str)).split(', '))
    )
).reset_index()
themes.rename(columns={'theme': 'themes'}, inplace=True)
themes
# Out:
#             id                                             themes
# 0      1000001  Quirky and endearing relationships|Laugh-out-l...
# 1      1000002  Intense violence and sexual transgression|Endu...
# 2      1000003  Quirky and endearing relationships|Humanity an...
# 3      1000004  Intense violence and sexual transgression|Chal...
# 4      1000005  Captivating relationships and charming romance...
# ...        ...                                                ...
# 24503  1762425     Erotic relationships and desire|Song and dance
# 24504  1819348  Intense violence and sexual transgression|Twis...
# 24505  1826155  and slasher horror|gruesome|and terrifying hor...
# 24506  1835643  Intriguing and suspenseful murder mysteries|Tw...
# 24507  1849827  Faith and religion|and forgiveness|sin|Faith a...
#
# [24508 rows x 2 columns]

# %%
movie = pd.merge(movies, genres, on = 'id')
movie = pd.merge(movie, countries, on = 'id')
movie = pd.merge(movie, languages, on = 'id')
movie = pd.merge(movie, actors, on = 'id')
movie = pd.merge(movie, crew, on = 'id')
movie = pd.merge(movie, studios, on = 'id')
movie = pd.merge(movie, themes, on = 'id')
movie = pd.merge(movie, posters, on = 'id')
movie
# Out:
#             id                               name    date  \
# 0      1000001                             Barbie  2023.0
# 1      1000002                           Parasite  2019.0
# 2      1000003  Everything Everywhere All at Once  2022.0
# 3      1000004                         Fight Club  1999.0
# 4      1000005                         La La Land  2016.0
# ...        ...                                ...     ...
# 23259  1628265     Coldd Lassi Aur Chicken Masala  2019.0
# 23260  1659939                           Marriage  2022.0
# 23261  1664306                             Fixerr  2019.0
# 23262  1762425                      Pretty Things  2005.0
# 23263  1835643                       Angela Black  2021.0
#
#                                                 tagline  \
# 0                      She's everything. He's just Ken.
# 1                           Act like you own the place.
# 2      The universe is so much bigger than you realize.
# 3                               Mischief. Mayhem. Soap.
# 4                        Here's to the fools who dream.
# ...                                                 ...
# 23259                                               NaN
# 23260                                               NaN
# 23261                                               NaN
# 23262                                               NaN
# 23263                 Push something enough, it breaks.
#
#                                              description  minute  rating  \
# 0      Barbie and Ken are having the time of their li...   114.0    3.86
# 1      All unemployed, Ki-taek's family takes peculia...   133.0    4.56
# 2      An aging Chinese immigrant is swept up in an i...   140.0    4.30
# 3      A ticking-time-bomb insomniac and a slippery s...   139.0    4.27
# 4      Mia, an aspiring actress, serves lattes to mov...   129.0    4.09
# ...                                                  ...     ...     ...
# 23259  Fate brings ex-lovers Nitya, Indie Spice's hea...   336.0     NaN
# 23260  Marriage sees married couple Ian and Emma nego...   240.0     NaN
# 23261  ATS Officer Jayveer Malik’s stands suspended a...   324.0     NaN
# 23262  A look into the world of 20th century burlesqu...    90.0     NaN
# 23263  Angela Black leads a seemingly idyllic life wi...   270.0     NaN
#
#                                         genres      countries Language  ...  \
# 0                             Comedy|Adventure         UK|USA  English  ...
# 1                        Comedy|Drama|Thriller    South Korea      NaN  ...
# 2      Comedy|Action|Science Fiction|Adventure            USA      NaN  ...
# 3                                        Drama    Germany|USA  English  ...
# 4                   Comedy|Drama|Romance|Music  Hong Kong|USA  English  ...
# ...                                        ...            ...      ...  ...
# 23259                                    Drama          India    Hindi  ...
# 23260                                    Drama             UK  English  ...
# 23261                                    Drama          India    Hindi  ...
# 23262                              Documentary            USA  English  ...
# 23263                                    Drama             UK  English  ...
#
#                                                    Sound  \
# 0      Robert Sharman|Chelsea Body|Dan Kenyon|Ai-Ling...
# 1      Choi Tae-young|Eun Hee-soo|Shin i Na|Kim Byung...
# 2      Jason Charbonneau|Ian Chase|Alexandra Fehrman|...
# 3      Ren Klyce|Richard Hymns|Steve Boeddeker|Jeff W...
# 4      Kevin Becker|James Ashwill|Blake Collins|John ...
# ...                                                  ...
# 23259                                                NaN
# 23260  Wayne Brooks|Nigel Heath|Richard Munns|Stuart ...
# 23261                                                NaN
# 23262                                                NaN
# 23263                                                NaN
#
#                                          Special effects         Story  \
# 0      Lucy Thompson|Alex Robinson|Peter Treece|Sam P...           NaN
# 1                                                    NaN  Bong Joon-ho
# 2                     Charlie Bruchez|Jonathan Kombrinck           NaN
# 3                              Cliff Wenger|Wayne Burnes           NaN
# 4                                            Jeremy Hays           NaN
# ...                                                  ...           ...
# 23259                                                NaN           NaN
# 23260                                                NaN           NaN
# 23261                                                NaN           NaN
# 23262                                                NaN           NaN
# 23263                                                NaN           NaN
#
#                                                   Stunts   Title design  \
# 0      Ingrid Kleinig|Roy Taylor|Donny Bailey|Hannah ...            NaN
# 1      Yoo Sang-seob|Oh Se-yeong|Yoo Mi-jin|Kwon Ji-h...            NaN
# 2      Narayana Cabral|Elisabeth P. Carpenter|Timothy...            NaN
# 3      Michael Runyard|Jeff Imada|Richard Cetrone|Dav...            NaN
# 4      Nicolas Bosc|Brandon Cornell|Olivia Courtney|D...  Michael Riley
# ...                                                  ...            ...
# 23259                                                NaN            NaN
# 23260                                                NaN            NaN
# 23261                                                NaN            NaN
# 23262                                                NaN            NaN
# 23263                                                NaN            NaN
#
#                                           Visual effects  \
# 0      Nick Irving Allen|François Dumoulin|Erin Hewit...
# 1      Hong Jeong-ho|Chan-jin Chris Kim|Jang Mi-jin|K...
# 2      Evan Halleck|Zak Stoltz|Jeff Desom|Ethan Feldb...
# 3      Carlos Saldanha|Joshua I. Kolden|Andrea D'Amic...
# 4                  Chris LeDoux|Tim LeDoux|Jason Sanford
# ...                                                  ...
# 23259                                                NaN
# 23260                                                NaN
# 23261                                                NaN
# 23262                                                NaN
# 23263                                                NaN
#
#                                       Writer  \
# 0                 Noah Baumbach|Greta Gerwig
# 1      Kim Dae-hwan|Bong Joon-ho|Han Jin-won
# 2               Daniel Kwan|Daniel Scheinert
# 3               Jim Uhls|Andrew Kevin Walker
# 4                            Damien Chazelle
# ...                                      ...
# 23259                  Doris Dey|Jaya Mishra
# 23260                                    NaN
# 23261                                    NaN
# 23262                            Liz Goldwyn
# 23263                                    NaN
#
#                                                  studios  \
# 0      NB/GG Pictures|Warner Bros. Pictures|Heyday Fi...
# 1                                           Barunson E&A
# 2      Year of the Rat|IAC Films|Ley Line Entertainme...
# 3      Regency Enterprises|20th Century Fox|Taurus Fi...
# 4      Summit Entertainment|Gilbert Films|Marc Platt ...
# ...                                                  ...
# 23259                    Linga Bhairavi Devi Productions
# 23260    The Forge Entertainment|All3Media|The Money Men
# 23261                                   Balaji Telefilms
# 23262                                                HBO
# 23263                              Two Brothers Pictures
#
#                                                   themes  \
# 0      Quirky and endearing relationships|Laugh-out-l...
# 1      Intense violence and sexual transgression|Endu...
# 2      Quirky and endearing relationships|Humanity an...
# 3      Intense violence and sexual transgression|Chal...
# 4      Captivating relationships and charming romance...
# ...                                                  ...
# 23259  Captivating relationships and charming romance...
# 23260  Moving relationship stories|Emotional and touc...
# 23261  High speed and special ops|Intense violence an...
# 23262     Erotic relationships and desire|Song and dance
# 23263  Intriguing and suspenseful murder mysteries|Tw...
#
#                                                   poster
# 0      https://a.ltrbxd.com/resized/film-poster/2/7/7...
# 1      https://a.ltrbxd.com/resized/film-poster/4/2/6...
# 2      https://a.ltrbxd.com/resized/film-poster/4/7/4...
# 3      https://a.ltrbxd.com/resized/film-poster/5/1/5...
# 4      https://a.ltrbxd.com/resized/film-poster/2/4/0...
# ...                                                  ...
# 23259  https://a.ltrbxd.com/resized/film-poster/9/8/2...
# 23260  https://a.ltrbxd.com/resized/film-poster/1/1/8...
# 23261  https://a.ltrbxd.com/resized/film-poster/9/8/2...
# 23262                                                NaN
# 23263  https://a.ltrbxd.com/resized/film-poster/1/1/8...
#
# [23264 rows x 45 columns]

# %%
movie.columns
# Out:
# Index(['id', 'name', 'date', 'tagline', 'description', 'minute', 'rating',
#        'genres', 'countries', 'Language', 'Primary language',
#        'Spoken language', 'actors', 'Additional directing',
#        'Additional photography', 'Art direction', 'Assistant director',
#        'Camera operator', 'Casting', 'Choreography', 'Cinematography',
#        'Co-director', 'Composer', 'Costume design', 'Director', 'Editor',
#        'Executive producer', 'Hairstyling', 'Lighting', 'Makeup',
#        'Original writer', 'Producer', 'Production design', 'Set decoration',
#        'Songs', 'Sound', 'Special effects', 'Story', 'Stunts', 'Title design',
#        'Visual effects', 'Writer', 'studios', 'themes', 'poster'],
#       dtype='object')

# %%
cols_to_combine = [
    'tagline', 'description', 'genres', 'countries', 'Language', 'Primary language', 'Spoken language',
    'actors', 'Additional directing', 'Additional photography', 'Art direction', 'Assistant director',
    'Camera operator', 'Casting', 'Choreography', 'Cinematography', 'Co-director', 'Composer',
    'Costume design', 'Director', 'Editor', 'Executive producer', 'Hairstyling', 'Lighting', 'Makeup',
    'Original writer', 'Producer', 'Production design', 'Set decoration', 'Songs', 'Sound',
    'Special effects', 'Story', 'Stunts', 'Title design', 'Visual effects', 'Writer', 'studios', 'themes'
]

movie['combined'] = movie[cols_to_combine].fillna('').agg('|'.join, axis=1)

# %%
tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(movie['combined'])

# %%
top_similarities = {}

for idx in range(tfidf_matrix.shape[0]):
    cosine_sim = linear_kernel(tfidf_matrix[idx], tfidf_matrix).flatten()
    
    # Get top 10 excluding itself
    top_indices = cosine_sim.argsort()[-11:-1][::-1]
    
    # Store as (movieId, similarity) tuples
    top_similarities[movie.iloc[idx]['movieId']] = [
        (movie.iloc[i]['movieId'], round(cosine_sim[i], 4)) for i in top_indices
    ]

# %%
similar_df = pd.DataFrame([
    {'movieId': key, 'similar_movies': value}
    for key, value in top_similarities.items()
])

# %%
with open("similar_movies.pkl", "wb") as f:
    pickle.dump(similar_df, f)

# %%
with open('movie.pkl', 'wb') as f:
    pickle.dump(movie, f)
